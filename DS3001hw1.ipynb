# %% [markdown]
# <a href="https://colab.research.google.com/github/sqr8ap/DS3001Assignments/blob/main/DS3001hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment: Programming Review

# %% [markdown]
# #### Q1.

# %% [markdown]
# 3. I was a little surprised to see that the median salary for clinical social work is 50,390. I know that social work is not known for paying well, but I expected clinical social work to have a higher median salary than 50k given the similarity between the responsibilities of a clinical social worker and a clinical psychologist.
# 4. Ranked list (best to worst): data scientist, information security analyst, web developer, psychologist, actuary, financial analyst, speech-language pathologist, clinical social worker. I ranked these jobs pretty subjectively but also tried to factor objective pros and cons into the rankings. I put data scientist as number 1 because I personally intend to pursue data science of some sort after I graduate, but it is also a rapidly growing field with massive prospects for the future. I put information security analyst as 2 because it pays really well and has predicted growth of 35%, which indicates this field is also rapidly growing and in demand. I put web developer as 3 because there is large predicted growth and solid pay. I put psychologist as number 4 because that I am also heavily considering that path, and because there will likely be a steady need for licensed psychologists in the next few decades, so job security is good. I put actuary next due to the high salary and large growth expected. After that I put financial analyst, which is another well-paying job with solid job security. I ranked speech-language pathologist and clinical social worker as 7 and 8, as I don't personally have much interest in pursuing these positions, and social work specifically is known for being very grueling with little pay off.

# %% [markdown]
# #### Q2.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,1,50)
y = np.log(x)
z = np.exp(x)
# Out:
# <ipython-input-15-e8a52f5964b2>:2: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)

# %%
plt.scatter(x,y,label='Natural Log')
plt.scatter(x,z,label='Exponential')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Natural Log and Exponential Functions')
plt.legend(loc='lower right')

plt.show()

# %%
x = np.linspace(-6.6,6.5,100)
y = np.sin(x)
z = np.cos(x)

# %%
plt.scatter(x,y)
plt.scatter(x,z)

# %%
plt.plot(x,y,label='Sine')
plt.plot(x,z,label='Cosine')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Sine and Cosine Functions')
plt.legend(loc='lower left')

plt.show()
